# %%
import matplotlib.pyplot as plt
import numpy as np
import os
import PIL
import tensorflow as tf
import re
from keras.layers import Dense
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from keras.utils import to_categorical
import pandas as pd
import cv2
from sklearn.cluster import KMeans
from scipy.spatial import distance
import warnings
from sklearn.cluster import KMeans
import requests
from io import BytesIO
import webcolors

warnings.simplefilter(action='ignore')

# %%
def corrigir_caracteres_mal_codificados(texto):
  
    mapeamento_substituicao = {
        "Ã¡": "á",
        "Ã©": "é",
       
    }

  
    for chave, valor in mapeamento_substituicao.items():
        texto = texto.replace(chave, valor)

    return texto

# %%
def classifica_item(name):
    if re.search('Armário', name):
        return "Armario Cozinha"
    
    if re.search('Cozinha Compacta', name):
        return "Conjunto Cozinha"
    
    if re.search("BalcÃ£o de Cozinha", name):
        return "Balcao de Cozinha"
    
    if re.search("Paneleiro", name):
        return "Paneleiro"
    
    if re.search("Cozinha Completa", name):
        return "Cozinha completa"
    
    return "Outro"

def extract_colors_from_image(image_url, num_colors=5):
    response = requests.get(image_url)
    image = Image.open(BytesIO(response.content))
    image = image.resize((100, 100))
    image_array = np.array(image)
    pixels = image_array.reshape(-1, 3)
    kmeans = KMeans(n_clusters=num_colors, random_state=0).fit(pixels)
    cluster_centers = kmeans.cluster_centers_.astype(int)
    return cluster_centers

df = pd.read_csv(r"D:\testekeras\basedados\produtos.csv", sep=",", encoding="latin-1")

image_urls = pd.melt(df, id_vars=['nome'], value_vars=['img0', 'img1'], var_name='fonte', value_name='imagem')
image_urls.dropna(subset=['imagem'], inplace=True) 

num_colors = 5

lista_dicts = []
for i, row in image_urls.iterrows():
    dict_items = {}
  
    cores_da_imagem = extract_colors_from_image(row['imagem'], num_colors)
    
    dict_items['Nome'] = row['nome']
    dict_items['CodigoRgb'] = cores_da_imagem
    dict_items['imagem'] = row['imagem']
    lista_dicts.append(dict_items)

df_final = pd.DataFrame(lista_dicts)
df_final['tipo'] = df_final['Nome'].apply(classifica_item)
df_final.to_csv("dados_finais_com_rgb.csv", index=False)

# %%
df_produtos = pd.read_csv(r"D:\testekeras\dados_finais_com_rgb.csv",sep=",")
df_produtos.fillna(0, inplace=True)
df_produtos['Nome'] = df_produtos['Nome'].apply(lambda k: corrigir_caracteres_mal_codificados(k))

# %%
df_produtos
# Out:
#                                                   Nome  \
# 0    Cozinha Compacta Iluminata 8 PT 4 GV Branca e ...
# 1          Armário Aéreo Canelone com Vidro 3 PT Preto
# 2            Armário Aéreo Evidence 3 PT Branco 120 cm
# 3         BalcÃ£o de Cozinha Iluminata 2 PT Mint 80 cm
# 4                          Paneleiro Maxxi 2 PT Branco
# ..                                                 ...
# 221  Cozinha Compacta Com Balcao Para Pia 10027x170...
# 222  Armário de Cozinha Completa 325cm Rustic Emill...
# 223  Armário de Cozinha Completa Madesa Emilly Danc...
# 224       BalcÃ£o de Cozinha Evidence 3 PT 2 GV Branco
# 225       Cozinha Completa Atena 10 PT 1 GV Preto Onix
#
#                                              CodigoRgb  \
# 0    [[125 113 101]\n [206 201 195]\n [ 40  36  29]...
# 1    [[254 254 254]\n [ 67  68  66]\n [ 30  31  30]...
# 2    [[254 254 254]\n [178 178 178]\n [231 231 231]...
# 3    [[253 253 251]\n [183 174 163]\n [229 113  69]...
# 4    [[240 239 239]\n [200 199 199]\n [254 254 254]...
# ..                                                 ...
# 221  [[ 55  51  46]\n [201 197 192]\n [116 111 102]...
# 222  [[253 253 251]\n [125  98  72]\n [190 182 171]...
# 223  [[252 252 250]\n [102  81  65]\n [204 180 152]...
# 224  [[227 227 226]\n [168 169 167]\n [254 254 254]...
# 225  [[ 69  69  74]\n [253 253 253]\n [ 19  19  20]...
#
#                                                 imagem               tipo
# 0    https://static.mobly.com.br/p/GENIALFLEX-Cozin...   Conjunto Cozinha
# 1    https://static.mobly.com.br/p/Politorno-ArmC3A...              Outro
# 2    https://static.mobly.com.br/p/Poliman-ArmC3A1r...              Outro
# 3    https://static.mobly.com.br/p/GENIALFLEX-BalcC...  Balcao de Cozinha
# 4    https://static.mobly.com.br/p/Kappesberg-Panel...          Paneleiro
# ..                                                 ...                ...
# 221  https://static.mobly.com.br/p/Poliman-Cozinha-...   Conjunto Cozinha
# 222  https://static.mobly.com.br/p/Madesa-ArmC3A1ri...   Cozinha completa
# 223  https://static.mobly.com.br/p/Madesa-ArmC3A1ri...   Cozinha completa
# 224  https://static.mobly.com.br/p/Poliman-BalcC3A3...  Balcao de Cozinha
# 225  https://static.mobly.com.br/p/Gralar-Cozinha-C...   Cozinha completa
#
# [226 rows x 4 columns]

# %%
def extract_colors_from_image(image_url, num_colors=5):
    response = requests.get(image_url)
    image = Image.open(BytesIO(response.content))
    image = image.resize((100, 100))
    image_array = np.array(image)
    pixels = image_array.reshape(-1, 3)
    kmeans = KMeans(n_clusters=num_colors, random_state=0).fit(pixels)
    cluster_centers = kmeans.cluster_centers_.astype(int)
    return cluster_centers


df_treinamento = pd.read_csv(r"D:\testekeras\dados_finais_com_rgb.csv",sep=",",encoding="latin-1")


df_avaliacao = pd.read_csv(r"D:\testekeras\avaliacao.csv",sep=";",encoding="latin-1")


X_train = []
y_train = []

for i, row in df_treinamento.iterrows():
    if isinstance(row['imagem'], str):
        cores_da_imagem = extract_colors_from_image(row['imagem'])
        atributos = cores_da_imagem.tolist()  
        X_train.append(atributos)
        y_train.append(row['tipo']) 


X_test = []
y_test = []

for i, row in df_avaliacao.iterrows():
    if isinstance(row['imagem'], str):
        cores_da_imagem = extract_colors_from_image(row['imagem'])
        atributos = cores_da_imagem.tolist() 
        X_test.append(atributos)
        y_test.append(row['tipo']) 


label_encoder = LabelEncoder()
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)


y_train_encoded = to_categorical(y_train_encoded)
y_test_encoded = to_categorical(y_test_encoded)

model = Sequential()
model.add(Dense(128, input_dim=3, activation='relu')) 
model.add(Dense(64, activation='relu'))
model.add(Dense(len(label_encoder.classes_), activation='softmax'))


model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])


model.fit(np.array(X_train), y_train_encoded, epochs=10, batch_size=32, validation_split=0.2)


accuracy = model.evaluate(np.array(X_test), y_test_encoded)
print(f"Acurácia do modelo: {accuracy[1]}")
